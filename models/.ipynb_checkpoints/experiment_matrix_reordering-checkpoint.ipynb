# %%
import numpy as np
import pandas as pd

# %%
import scipy
import pylab
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import squareform

# %%
# %matplotlib inline

# %%
from pymongo import MongoClient

client = MongoClient()

db = client['glvis_db']
val_collection = db['flattened']

# %%
def query(term):
    pipeline = {
        '$text': {'$search': term}
    }

    return list(val_collection.find(pipeline))

# %%
res = query('\"best ever\""')

# %%
vectors = np.array([elm['val'] for elm in res])

# %%
vectors.shape
# Out:
# (76, 2048)

# %%
var = vectors.var(axis=0)

# %%
sorted_ids = var.argsort()[::-1]

# %%
vectors.sort()

# %%
D = vectors[:,sorted_ids][:20, :10]

# %%
vectors.shape
# Out:
# (76, 2048)

# %%
df = pd.DataFrame(vectors[:,100])

# %%
df.to_csv('upload.tsv', sep='\t')

# %%
D = vectors[:,sorted_ids][:20, :10]
fig = pylab.figure(figsize=(8,8))
axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
im = axmatrix.matshow(D, aspect='auto', origin='lower', cmap=pylab.cm.YlGnBu)
axmatrix.set_xticks([])
axmatrix.set_yticks([])
# Out:
# []

# %%
def plot_along_example(D, method):
    # Compute and plot first dendrogram.
    fig = pylab.figure(figsize=(50,50))
    ax1 = fig.add_axes([0.09,0.1,0.2,0.6])
    Y = sch.linkage(D, method=method)
    Z1 = sch.dendrogram(Y, orientation='left')
    idx1 = Z1['leaves']
    ax1.set_xticks([])
    ax1.set_yticks([])

    # Plot distance matrix.
    axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
    T = D[idx1, :]
    im = axmatrix.matshow(T, aspect='auto', origin='lower', cmap=pylab.cm.YlGnBu)
    axmatrix.set_xticks([])
    axmatrix.set_yticks([])

    # Plot colorbar.
    axcolor = fig.add_axes([0.91,0.1,0.02,0.6])
    pylab.colorbar(im, cax=axcolor)
    fig.show()

# %%
def plot_along_dim(D, method):
    # Compute and plot first dendrogram.
    fig = pylab.figure(figsize=(50,50))
    ax1 = fig.add_axes([0.09,0.1,0.2,0.6])
    Y = sch.linkage(D, method=method)
    Z1 = sch.dendrogram(Y, orientation='left')
    idx1 = Z1['leaves']
    ax1.set_xticks([])
    ax1.set_yticks([])

    # Plot distance matrix.
    axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
    T = D[idx1, :]
    im = axmatrix.matshow(T, aspect='auto', origin='lower', cmap=pylab.cm.YlGnBu)
    axmatrix.set_xticks([])
    axmatrix.set_yticks([])

    # Plot colorbar.
    axcolor = fig.add_axes([0.91,0.1,0.02,0.6])
    pylab.colorbar(im, cax=axcolor)
    fig.show()

# %%
D = vectors[:,sorted_ids][:10, :10]

plot_along_example(D, method='centroid')
plot_along_dim(D.T, method='centroid')

# %%
# Generate random features and distance matrix.
size = 2000
x = scipy.rand(size)
D = scipy.zeros([size,size])
for i in range(size):
    for j in range(size):
        D[i,j] = abs(x[i] - x[j])

condensedD = squareform(D)

# Compute and plot first dendrogram.
Y = sch.linkage(condensedD, method='centroid')
Z1 = sch.dendrogram(Y, orientation='left')

# Compute and plot second dendrogram.
Y = sch.linkage(condensedD, method='single')
Z2 = sch.dendrogram(Y)

# Plot distance matrix.
axmatrix = fig.add_axes([0.3,0.1,0.6,0.6])
idx1 = Z1['leaves']
idx2 = Z2['leaves']
D = D[idx1,:]
D = D[:,idx2]
im = axmatrix.matshow(D, aspect='auto', origin='lower', cmap=pylab.cm.YlGnBu)
axmatrix.set_xticks([])
axmatrix.set_yticks([])

# Plot colorbar.
axcolor = fig.add_axes([0.91,0.1,0.02,0.6])
pylab.colorbar(im, cax=axcolor)
fig.show()
fig.savefig('dendrogram.png')

# %%
# import widget classes and instantiate Network instance
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
# generate random matrix
num_rows = 500
num_cols = 10
np.random.seed(seed=100)
mat = np.random.rand(num_rows, num_cols)

# make row and col labels
rows = range(num_rows)
cols = range(num_cols)
rows = [str(i) for i in rows]
cols = [str(i) for i in cols]

# make dataframe 
df = pd.DataFrame(data=mat, columns=cols, index=rows)

# %%
df = pd.DataFrame(vectors[:, :100])

# %%
net.load_df(df)
net.cluster(enrichrgram=False)
net.widget()
# Out:
# clustergrammer_widget(network='{"row_nodes": [{"name": 0, "ini": 76, "clust": 53, "rank": 62, "rankvar": 47, "…

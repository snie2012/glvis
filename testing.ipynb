# %%
import gensim
import numpy as np

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
model.most_similar(positive=['woman', 'king'], negative=['man'])
# Out:
# [('queen', 0.7118192911148071),
#  ('monarch', 0.6189674139022827),
#  ('princess', 0.5902431607246399),
#  ('crown_prince', 0.5499460697174072),
#  ('prince', 0.5377321243286133),
#  ('kings', 0.5236844420433044),
#  ('Queen_Consort', 0.5235945582389832),
#  ('queens', 0.5181134343147278),
#  ('sultan', 0.5098593235015869),
#  ('monarchy', 0.5087411999702454)]

# %%
model.get_vector('queen')
# Out:
# array([ 0.00524902, -0.14355469, -0.06933594,  0.12353516,  0.13183594,
#        -0.08886719, -0.07128906, -0.21679688, -0.19726562,  0.05566406,
#        -0.07568359, -0.38085938,  0.10400391, -0.00081635,  0.1328125 ,
#         0.11279297,  0.07275391, -0.046875  ,  0.06591797,  0.09423828,
#         0.19042969,  0.13671875, -0.23632812, -0.11865234,  0.06542969,
#        -0.05322266, -0.30859375,  0.09179688,  0.18847656, -0.16699219,
#        -0.15625   , -0.13085938, -0.08251953,  0.21289062, -0.35546875,
#        -0.13183594,  0.09619141,  0.26367188, -0.09472656,  0.18359375,
#         0.10693359, -0.41601562,  0.26953125, -0.02770996,  0.17578125,
#        -0.11279297, -0.00411987,  0.14550781,  0.15625   ,  0.26757812,
#        -0.01794434,  0.09863281,  0.05297852, -0.03125   , -0.16308594,
#        -0.05810547, -0.34375   , -0.17285156,  0.11425781, -0.09033203,
#         0.13476562,  0.27929688, -0.04980469,  0.12988281,  0.17578125,
#        -0.22167969, -0.01190186,  0.140625  , -0.18164062,  0.11865234,
#         0.16113281,  0.21484375, -0.21191406,  0.12695312, -0.10009766,
#         0.13671875,  0.12695312,  0.01531982,  0.10449219, -0.02783203,
#        -0.06030273,  0.0222168 ,  0.18164062, -0.06738281,  0.04907227,
#         0.15429688, -0.25      ,  0.13964844,  0.29492188,  0.10644531,
#         0.3359375 , -0.22265625, -0.125     , -0.05297852,  0.19238281,
#         0.06835938,  0.06982422, -0.05200195,  0.14453125,  0.00448608,
#        -0.01013184, -0.1484375 ,  0.21777344, -0.1953125 , -0.390625  ,
#         0.07763672, -0.57421875, -0.07910156, -0.04052734, -0.1875    ,
#         0.25390625,  0.15722656,  0.125     ,  0.140625  ,  0.20117188,
#        -0.05859375,  0.16894531, -0.28125   ,  0.171875  ,  0.19140625,
#         0.12109375, -0.15039062, -0.00695801, -0.23730469,  0.13964844,
#        -0.00836182, -0.04711914,  0.14648438, -0.05688477,  0.10205078,
#         0.08447266,  0.21191406, -0.01831055,  0.50390625, -0.04858398,
#         0.22167969, -0.25585938,  0.03417969,  0.15820312, -0.03369141,
#         0.06738281, -0.25195312,  0.04614258, -0.07275391,  0.07958984,
#         0.04223633, -0.00128937,  0.20214844, -0.13085938, -0.06030273,
#         0.0378418 ,  0.13574219,  0.11181641, -0.24609375, -0.23925781,
#        -0.23632812, -0.04321289, -0.02905273,  0.23535156, -0.00390625,
#        -0.05029297,  0.18457031,  0.50390625, -0.00668335, -0.03466797,
#        -0.07568359,  0.06152344, -0.31445312, -0.03759766,  0.23632812,
#        -0.12792969,  0.15429688,  0.296875  ,  0.02709961, -0.17089844,
#        -0.22460938,  0.00241089,  0.10595703, -0.03320312,  0.0145874 ,
#        -0.21582031,  0.24707031, -0.07421875, -0.10205078,  0.16894531,
#        -0.05029297,  0.20800781, -0.03857422, -0.22265625,  0.27539062,
#        -0.05957031, -0.01757812,  0.01794434,  0.08886719,  0.12890625,
#         0.18261719,  0.14453125,  0.10400391, -0.1328125 , -0.32617188,
#         0.00386047, -0.11376953, -0.05053711, -0.13085938,  0.02209473,
#        -0.14648438,  0.10742188,  0.23046875,  0.15234375,  0.22753906,
#         0.04833984,  0.06787109, -0.06787109, -0.2578125 ,  0.11230469,
#         0.00363159, -0.12011719, -0.21289062,  0.11230469,  0.12158203,
#         0.06835938,  0.04907227,  0.2734375 , -0.00302124, -0.00378418,
#         0.00193787,  0.1875    , -0.29101562,  0.09033203,  0.26367188,
#        -0.25585938, -0.28710938, -0.40820312,  0.10546875,  0.39648438,
#        -0.07275391, -0.04321289, -0.06347656, -0.00060272, -0.11523438,
#         0.31445312, -0.22265625,  0.13574219, -0.01965332,  0.15332031,
#         0.00360107, -0.12011719,  0.06494141,  0.16210938, -0.16699219,
#         0.03271484, -0.00350952,  0.18847656,  0.19335938,  0.1328125 ,
#         0.06787109, -0.34179688, -0.08349609, -0.29492188, -0.02099609,
#         0.08886719,  0.32421875, -0.36914062, -0.0859375 , -0.04956055,
#         0.13183594,  0.04418945,  0.359375  ,  0.21484375,  0.265625  ,
#        -0.2734375 ,  0.23535156,  0.11425781,  0.08789062,  0.1875    ,
#        -0.33203125,  0.15136719, -0.03613281, -0.11914062,  0.27734375,
#         0.10839844, -0.07275391,  0.23242188,  0.00219727,  0.23828125,
#        -0.24902344, -0.12353516, -0.15917969, -0.00601196,  0.14550781,
#        -0.00460815, -0.22558594, -0.37890625, -0.37695312, -0.08251953,
#        -0.04125977,  0.16796875, -0.046875  ,  0.16308594,  0.15429688],
#       dtype=float32)

# %%
vocab = np.array(list(model.vocab.keys()))

# %%
import random

# %%
sample_size = 1000
sample = random.sample(range(0, len(vocab)), sample_size)

# %%
vectors = []
for w in vocab[sample]:
    vectors.append(model.get_vector(w))
vectors = np.array(vectors)

# %%
from sklearn.manifold import TSNE

# %%
embedded = TSNE(n_components=2).fit_transform(vectors)

# %%
vocab = list(model.vocab.keys())

sample_words = [vocab[i] for i in random.sample(range(0, len(vocab)), sample_size)]

sample_vectors = [model.get_vector(w) for w in sample_words]

embedded_vectors = TSNE(n_components=2).fit_transform(np.array(vectors))

# %%
sample_words
# Out:
# ['Rowena_Kandler_owner',
#  'MedaSorb',
#  'Capital_Proprietary_Limited',
#  'Lana_Calloway_president',
#  'Immersing_herself',
#  'Dishwalla',
#  'Fabric_Switches',
#  'PRESS_ARCHIVES',
#  'folow',
#  'TREASURER',
#  'Roasted_Beet_Salad',
#  'Bresnitz',
#  'Klatka',
#  'Micro_Cap_Investors',
#  '6Q',
#  'Haddrick',
#  'Teacher_Pet',
#  'Linux_Netware',
#  'Morgan_Spurlock_documentary',
#  'LIMITED_ACN',
#  'Triwizard_Cup',
#  'WASHINGTON_TIMES_EDITORIAL',
#  'rapid',
#  'urban_slums',
#  '##RC',
#  'Follese',
#  'Kay_Tanda',
#  'Faraz_Sanei',
#  'anthropomorphize_animals',
#  'HARRIETTE_COLE',
#  'Kukurantumi',
#  'George_Shiffler_Gartner',
#  'Wachovia_Vitner',
#  'Densetsu',
#  'ExecSense_Webinars',
#  'vaginal_mucosa',
#  'FORWARD_LOOKING_STATEMENTS',
#  'Mitco',
#  'Thunda',
#  'Sogomonian',
#  'HEARTLESS_thieves',
#  'Cavadas',
#  'goalkeeper_Jim_Provett',
#  'Johnny_DuPree',
#  'fox_hound',
#  'Tore_Halvorsen',
#  'CFG',
#  'Yorktowne_Drive',
#  'lang_nila',
#  'Ziegfeld_Follies_Girls',
#  'Meteorologist_Matt_Zidle',
#  'Swiftboat_ads',
#  'Sreedhar',
#  'China_Airlines_华航',
#  'AngloGold_Ashanti_AGA',
#  'favourties',
#  'Foundation_OREF',
#  'Corporation_NDIC',
#  'Apatar_Open',
#  'HP_outboards',
#  'RIDGE',
#  'Naji',
#  'Magowan_parted_ways',
#  'Kenseth_Roush_Racing',
#  'Secily_Ray',
#  'coxswain_Marcus_McElhenney',
#  'Ranganath',
#  'Project_Darkstar',
#  'microbicide_cream',
#  'BEE_codes',
#  'Ryncavage',
#  'soapie_Generations',
#  'nearness',
#  'Jeff_Horing',
#  'Dahal',
#  'URRC',
#  'bor_MORE',
#  'Knoff',
#  'USD1m',
#  'Oure',
#  'Staplin',
#  'sausage_stuffer',
#  'Lori_Corbin',
#  'KICKING_IT',
#  'Kristin_Karcsh',
#  'Vitol_Holding_BV',
#  'Hear_ye_hear',
#  'SHIMON_PERES',
#  'toweringly',
#  'Are_Greatly_Exaggerated',
#  'Vallon',
#  'Cessna_Conquest',
#  'La_Polar_LAP.SN',
#  'Narrowly_Beats',
#  'Advance_tickets',
#  'Kadish',
#  'HOLMDEL_NJ',
#  'Ba3',
#  'Spannuth',
#  'By_Mark_Curnutte',
#  'Joe_Alouf',
#  'Baptist_Convention',
#  'Bussola',
#  'GFA_missionaries',
#  'dej',
#  'Cum_Laude',
#  'drunken_drivers',
#  "don't_tread",
#  'BY_BETTY_DILLARD',
#  'wife_Shawn_Southwick',
#  'ricotta_ravioli',
#  'division_procedurally_investigates',
#  'pm_WJDX',
#  'Cvik',
#  'Kashif_Payne',
#  'Susser_Holdings',
#  'Saad_Hariri',
#  '##st_Infantry_Brigade',
#  'TARNISHED',
#  'Palm_Beach_FL',
#  'TextMagic_Messenger',
#  'Jay_Pecci',
#  'Teradata_Purpose_Built',
#  'Maserati_Corse',
#  'Giulini',
#  'JCP_Rewards',
#  'Mario_Danelo_kicked',
#  'fooled',
#  'capturers',
#  'SEAA',
#  'GCCF_relied',
#  'messieurs',
#  'b_g',
#  'Towan',
#  'Mitek_Systems_OTC_MITK.OB',
#  'silicone_hydrogel_lens',
#  'Wilton_Gregory',
#  'Ned_Yost',
#  'outer_eyewall',
#  'cancerdefine',
#  'AmCon_Contract_Manufacturing',
#  'M._Schlesinger',
#  'p_laintiff',
#  'writers_Noaki_Schwartz',
#  'JEANNINE_GAGE',
#  'Dendinger',
#  'By_Tessa_Thorniley',
#  'Le_Foll',
#  'Chunghwa_Picture',
#  'Chairman_Tom_Pauken',
#  'black_firefighter_Tennie',
#  'Symantec_OpenStorage',
#  'Barkell',
#  'Vitesse_Semiconductor_Corp.',
#  'Addlestone_Surrey',
#  'Awn',
#  'Tenaya_Middle',
#  'drawing_admiring_glances',
#  'RAD##',
#  'Lanny_Alta_Cocina',
#  'Danny_Gare',
#  'hate',
#  'Uddhav_Raj',
#  'Jeff_Boromisa',
#  'bxc4',
#  'Orissa_Sundergarh_district',
#  'Silverlake_Lounge',
#  'Artspace_Gallery',
#  'Guairuro',
#  'Liviakis_Financial_Communications',
#  'Hiromasa_Nakamura',
#  'R2_,7',
#  'small_molecule_PEGylation',
#  'Governor_KC_Chakrabarty',
#  'Maraman',
#  'NaN',
#  'LaRita',
#  'Marc_Goossens',
#  'legal_memos_justifying',
#  'Orne',
#  'Waly',
#  'Antonio_Basagoiti',
#  'Harry_Tchilinguirian_senior',
#  'Uranium_hexafluoride_gas',
#  'ARE_NOT_GUARANTEED',
#  'Giriraj_Kishore',
#  'Rata_Perata',
#  'Misty_Poe',
#  'Phra_Khru',
#  'Karni_cargo',
#  'dicamba',
#  'Peppler_Lake',
#  'E##A',
#  'unproven_hypothesis',
#  'CA_EITM',
#  'PowerBook_iBook_1GB_SODIMM',
#  'Amazon.com_Nasdaq_AMZN',
#  'Rukun_Tetangga',
#  'http://www.impaccompanies.com',
#  'Samangan',
#  'Randy_Moss_ReShard_Lee',
#  'prevalence',
#  'governor_Sukhumbhand_Paribatra',
#  'Vector_Informatik',
#  'Salme_Cook',
#  'backpackers',
#  'Ruks',
#  'Shofner',
#  'Powin',
#  'Assiut_eyewitnesses',
#  'Bald_Soprano',
#  'Prince_Kassim_Nakibinge',
#  'Eightfold',
#  'Contact_Ann_Killion',
#  'Soft_Matter',
#  'Grand_Rapids_Thunderhawks',
#  'Speaker_Lovemore_Moyo',
#  'LISA_PETTY',
#  'Stevenage',
#  'Intermediate_Equitation',
#  '###st_Ordnance_Battalion',
#  'junior_featherweight_titleholder',
#  'earthly_realm',
#  'Czarina_Mae_Arevalo',
#  'MZI_HealthCare_LLC',
#  'Bln_Won',
#  'Sitiawan',
#  'LATimes_Ext',
#  'DisneyFamily.com',
#  'WHL_Goaltender',
#  '###C_EV_concept',
#  'Amariana_Crenshaw',
#  'Narromine_Shire_Council',
#  'Lionbridge_Technologies_LIOX',
#  'Cowboy_Astronomer',
#  'Gonos',
#  'Peer_File_Sharing',
#  'Michelangelo_Creation',
#  'Beyaz',
#  'portolio',
#  'heftiest_fines',
#  'Chhay',
#  'radioactive_isotope_polonium',
#  'SCGA_Members',
#  'ruchika',
#  'MWH_Americas_Inc.',
#  'Zahra_stepmother',
#  'Taotao',
#  'Mahoning_Township',
#  'rider_Oscar_Pereiro',
#  'founder_Clay_Roueche',
#  'Bachir_Annane_scientist',
#  'Bryan_Cheplic_spokesman',
#  'Private_Postsecondary_Education',
#  'Eacho',
#  'Jay_Sigel',
#  'candidate_ponatinib',
#  'Brunken',
#  'Torreya',
#  'Matulaitis',
#  'NetVault',
#  'zoysiagrass',
#  'Clinical_Counsellor_Rhona',
#  'Robber',
#  'Raúl_Grijalva',
#  'Katelyn_Bastert',
#  'RFID_UHF',
#  'Twenty8Twelve_collection',
#  'http://www.sirius.com',
#  'Grandpa_Vanderhof',
#  'Dopey_crooks_Dimwitted_pair',
#  'Banu_Qurayza',
#  'prosecutor_Detlev_Mehlis',
#  '#-###_FIGHT',
#  'Moxie_Girlz_™',
#  'lambda_cyhalothrin',
#  'Alli_Smalley_scored',
#  'Nyuni_PSA',
#  'Maj._Lisa_Rudzinski',
#  'Feldman_CLU_ChFC',
#  'Mabrook',
#  'Dicenta',
#  'Lynn_Hettrick',
#  'Ganesh_Visarjan',
#  'Dr._Seham_Sergewa',
#  'Phil_Palmesano',
#  'Polarisation',
#  'Maulana_Abdul_Khaliq_Madrasi',
#  'Co._MRK',
#  'Vince_Rabil',
#  'porous_Indo_Bangla',
#  'Kawzenuk',
#  'Attari_railway',
#  'Carolyn_Robb_Hootkins',
#  'brown_bagging',
#  'Ener1_develops',
#  'Bonati_Spine_Institute',
#  'Wazee_Supper_Club',
#  'www.newyorklife.com',
#  'Naked',
#  'ELSI',
#  'THE_REAR_OF',
#  'Awfully_Big',
#  'NFkappaB',
#  'SaaScon_Computerworld_conferences',
#  'SoCon',
#  'THE_ALL_AMERICAN',
#  'al_Taayie',
#  'Assaggio',
#  'WP_USAT',
#  'Kherwar',
#  'Rick_Blatstein',
#  'Bejan',
#  'professor_Michel_Rieu',
#  'balefully',
#  'porch',
#  'fierceness',
#  'International_Korfball_Federation',
#  'MeCabrera_Kansas_City',
#  'Hurricanes_Tuomo_Ruutu',
#  'Cheeky_Watson',
#  'MercuryGate',
#  'ASP_Peter_Ogboi',
#  'ANOTHER_COUNTRY',
#  'S._Goldsman',
#  'motorcycles_mopeds',
#  "O'Malley_Greenburg",
#  'Lance_Legree',
#  'Elementa',
#  'manufacturer_Talgo',
#  'Assets_Relief_Program',
#  'JUST_HAPPENED',
#  'Implant_Sciences_filings',
#  'Tarkanian',
#  'By_KEVIN_NEVERS',
#  'Bugti_tribesmen',
#  'IndyMac_Bancorp_Inc.',
#  'mother_Erin_Runnion',
#  'Masserang',
#  'AP_NEWS_CATEGORIES',
#  'Sconex',
#  'Musical_Vanessa_Hudgens',
#  'Akkar_region',
#  'Firelands_Counseling',
#  'elderberry_liqueur',
#  'Ed_Galucki',
#  'Chatfield_Tupelo_Community',
#  'Ample_Finance',
#  'Woulfe_Mining',
#  'By_MARY_KIVO',
#  'WIFW',
#  'Anti_Authoritarian',
#  'MidFirst',
#  'coach_Rashid_Sidek',
#  'artificial_sweetener_aspartame',
#  'FGIC_Corp',
#  'thickly_forested',
#  'Thandar',
#  'Dave_Filoni',
#  'Download_##.#MB',
#  'Imaginative_Traveller',
#  'Gamal_Eid',
#  'eyes_staring_vacantly',
#  'Crewe_Lyceum',
#  'Abu_Shish',
#  'Magistrate_Patty_Shwartz',
#  'Inchon_Landing',
#  'Latta',
#  'Ophie',
#  'Ivo_Daalder_Brookings_Institution',
#  'teased_mercilessly',
#  'By_Philippa_Bourke',
#  'predecessor_Eduardo_Duhalde',
#  'McCluskey_Fawcett',
#  'By_PATRICK_JACKSON',
#  'jealousies_originate',
#  'GODWIN_TSA_Abuja',
#  'Thompson_Nickel_Belt',
#  'soot_sores',
#  'Mustafa_Kemal_Atatürk',
#  'Paulo_Sergio_Pinheiro',
#  'Scotch_Tape',
#  'Sid_Sperry',
#  'contact@pointcarbon.com',
#  'Miriam_Tuerk',
#  'Kypros_Kypri',
#  'Bali_bombers',
#  'Bluefield',
#  'Rodolfo_Ramos',
#  'Swiper',
#  'Kilvert',
#  'nineteen_fifties',
#  'Truthfully',
#  'Lacerda',
#  'defended_resiliently',
#  'Childe_Harold',
#  'Rayders',
#  'Clitherall_Lake',
#  'Quang_Ninh_Province',
#  'Jamil_Ezzo_Director',
#  'Decree_No.##',
#  'Basa_Pangelinan_Ballfield',
#  'Crozat',
#  'Diane_Pinakiewicz_president',
#  'floppy_diskette_plant',
#  'outlasted_Stanislas_Wawrinka',
#  'Jonathan_Daddia',
#  'LaMalfa',
#  'Shahban',
#  'TextFlow',
#  'Pourzanjani',
#  'G4techTV_Canada',
#  'Homosassa',
#  'Wilfy_Nite',
#  'Movement_PONM',
#  'Orapa_diamond',
#  'Engel_DN.Y.',
#  'THE_SPARK_Analyst',
#  'Chocolatiers',
#  'Alexander_Resch',
#  'Precious_Stones',
#  'Prickett',
#  'Result_Pregnancy',
#  'comedian_Frankie_Howerd',
#  'dayplanner',
#  'MIPS_TECHNOLOGIES_INC._RECONCILIATION',
#  'RAID_#/#/#/##',
#  'www.biosantepharma.com',
#  'Sufism_mystical',
#  'Poonch_Rawalakot',
#  'Indonesian_maid',
#  'Bjørnar',
#  'Kailuans',
#  'Bahman_Jalali',
#  'Mary_Bowen_Eggebraaten',
#  'www.michenerartmuseum.org',
#  'com_¬',
#  'Noriko_Aita',
#  'Corpuz',
#  're_architecting',
#  'Ciacchi',
#  'site_www.the_leaky',
#  'Leonhard_Fischer',
#  'Ajax_striker_Zlatan',
#  '---------------------------------------------------',
#  'Fraynd',
#  'linebacker_Dekoda_Watson',
#  'By_ROSS_GREGORY',
#  'totally_hallucinating',
#  'VIKING_SKULL',
#  'Arthur_Schopenhauer',
#  'Segway_HTs',
#  'Axio_Power',
#  'O2_OOM.L_Quote_Profile',
#  'spokeswoman_Julie_Gobin',
#  'Goodyear_tires',
#  'Afro_Centric',
#  'Shrs_Up',
#  'Bob_Corell',
#  'Michael_Manekin',
#  'Wollaton_Park',
#  'trentonian.com',
#  'raging_infernos_eased',
#  'Paul_Logothetis_contributed',
#  'Stoke_Rochford',
#  'Neil_MacKinnon_global',
#  'Jax_Teller',
#  'By_AARON_HOWARD',
#  'FLEA_MARKET_AND',
#  'Women_Infants',
#  'Newswires',
#  'Round_Table_Discussion',
#  'Pieczonka',
#  'Defenseman_Chris_Pronger',
#  'Dr_Sohail_Saleem',
#  'Continental_AG_CONG.DE',
#  'CPL_Aromas',
#  'Baruch_Lev',
#  'bint_Abdullah',
#  'recovering_meth_addict',
#  'Al_Shaali',
#  'SKATE_PARK',
#  'Timour',
#  'Mex_Tex',
#  'reporter_Doug_Zellmer',
#  'Capt._Juli_Liebler',
#  'Perrera',
#  'http://www.dendreon.com/',
#  'FABC',
#  'intricate_pleating',
#  '•_FRANCHUK',
#  'matrixed',
#  'Baechtel_Grove',
#  'meaty_morsels',
#  'regroup_refocus',
#  'Sotkamo',
#  'BILBAO_Spain',
#  'PRE_SALE',
#  'Philippe_Giaro_P.Geol',
#  'Workforce_Escarosa_Career',
#  'aqua',
#  'male_hypogonadism_PRO',
#  'Deutschneudorf',
#  'handed_tomahawk_dunk',
#  'IPFF',
#  'Drew_Beuerlein',
#  'wife_Aurea_Vazquez',
#  'Laurence_Bunin_senior',
#  'Dirk_T._Soulis',
#  'salesman_Tran_Manh',
#  'Gyasi_Gonzales',
#  'Fiocruz',
#  'THE_PROSPECTUS_CAREFULLY',
#  'JESSICA_HOLZER',
#  'include_uncontrollable_shivering',
#  'Kathleen_Wereszynski_Murray',
#  'Shelbi_Petty',
#  'ENZO',
#  'Technology_dr_Asheville',
#  'patented_webcasting_platform',
#  'Pasani',
#  'By_STEVE_WHITWORTH',
#  'Sean_Rutgerson',
#  'penguin_breeding_rookeries',
#  'Coren_Apicella',
#  'NGO_Janhit_Manch',
#  'Lesnaya',
#  'Hickeys',
#  'Countie',
#  'Alison_Deyette',
#  'numb',
#  'Jakaya',
#  'Dr_Foskey',
#  'nila',
#  'Surpluses',
#  'Ziko',
#  'Ceel_Huur',
#  'Powerful_thunderstorms',
#  'Kolodziejczak',
#  'mln_tons',
#  'http://www.davidpakman.com_http://www.davidpakman.com/memb_http://www.facebook.com/davidpakmanshow',
#  'Competency_Tests',
#  'OMAP##x',
#  'Anonma',
#  'Priyamvada',
#  'PLYMOUTH',
#  'Blackstairs',
#  'Chris_Moyles_Quiz',
#  "that'sa_whole_nother",
#  'AirTest_Technologies',
#  'Guido_Salvador_Carabajo',
#  'Pham_Ngoc',
#  'Palacenet.com',
#  'Kalle',
#  '------------_Cash_Flows',
#  'Wadoo',
#  'Bhagavatula',
#  'Madagascar_hissing_cockroach',
#  'BenQ_Siemens',
#  'By_OMER_GILLHAM',
#  'Cu_Ni',
#  'historical_facts_constitute',
#  'MCP#####',
#  'Triazine_Network',
#  'Tanbridge',
#  'Melanie_Augustin',
#  'intermittent_hypoxia',
#  'Jeanette_Balmer',
#  'Kutter_Harley_Davidson',
#  'Mahasangram',
#  'nucleosome_positioning',
#  'allegedly_snorting_cocaine',
#  'Punahou_grad',
#  'Duane_Kurisu',
#  'By_HEATHER_ZIEGLER',
#  'website_www.icrc.org',
#  'Yaqara',
#  'drama_Dark_Matter',
#  'pure_laine',
#  'Grandich_Letter',
#  'Brome_Place',
#  'treasurer_Wanda_Liczyk',
#  'Cliff_Bronstad',
#  'Colin_Wyers',
#  'JD_Drew_singled',
#  'William_Rusher',
#  'THE_MATRIX_REVOLUTIONS',
#  'Geatches',
#  'Underwater_robots_steadily',
#  'Bukit_Padang',
#  'Mohamed_Khaled',
#  'Greater_Mekong_subregion',
#  'Sir_Moti_Tikaram',
#  'X3_Terran_Conflict',
#  'By_BRANDY_UNDERWOOD',
#  'Nokia_N###_smartphone',
#  'Wine_Appreciation',
#  'GPIC_manufactures',
#  'TECUB',
#  'prestige_fragrance',
#  'genotypes',
#  'Taglia',
#  'Hilterbrand',
#  'RED_DEER',
#  'arrays_FPGA',
#  '###mΩ',
#  'megabytes',
#  'Neukoelln',
#  'Buckie_Thistle',
#  'Sharpei',
#  'jailA',
#  'leader_Warren_Truss',
#  'Norderum',
#  'Bipolar_II',
#  'migratory_waterfowl',
#  'ghostly_Princess_Leia',
#  'Berge_Pappas',
#  'Galapagos_penguin',
#  'lamb_shank',
#  'Liaquatabad_Town',
#  'Tun_Fuad_Stephens',
#  'Thuy_Pham',
#  'Erich_Huber_Guensthofer',
#  'Jamie_Arniel',
#  'Filipino_maids',
#  'Charles_Makley_ventured',
#  'checkpoints_buffer_zones',
#  'Nai',
#  'Hen_rik',
#  'Joselito_Mendoza',
#  'directional_keypad',
#  'Majuba_Hill',
#  'Patrick_Aubourg',
#  'Excitehotels.com_offers',
#  'Tiruvallur_districts',
#  'Matoian',
#  'Kandha_Kottai',
#  'DAB_IP',
#  'bulbous',
#  'Cliff_Hagan',
#  'Fairlands_Youth',
#  'Trigem_Computer',
#  'Climara',
#  'tu_es',
#  'Ratch',
#  'Capdevila',
#  'Kondakova',
#  'JITRA',
#  'Glassett',
#  'Major_Crimes',
#  'sucide_bombing',
#  'ArrowStream_Network',
#  'POCAHONTAS_Ark.',
#  'freshly_waxed',
#  'windows_xp_kaufen',
#  'Vinai_Thummalapally',
#  'Judge_Pedraz',
#  "Mischa_MEE'_shah",
#  'System_ABUS',
#  'Suzies',
#  'Solutions_Atos_Worldline',
#  'Wallmart',
#  'HP_Managed_Print',
#  'fitball_courses',
#  'machines_videocassette_recorders',
#  'Auburn_Onterio_McCalebb',
#  'Harrower',
#  'Azima_DLI_WATCHMAN',
#  'Ju_rez',
#  'porous_borders',
#  'Servaas',
#  'Rich_Beem',
#  'Walter_Koenig_Chekov',
#  'RealTime_Publishing_Announces',
#  'Flowmaster_mufflers',
#  'accessible_microSD_SDHC',
#  'Abraham_Iyambo',
#  'Kyrgyzstan_Uzbekistan_Tajikistan',
#  'Blolequin',
#  'AEDs_electrocardiograph_devices',
#  'shortfin_mako',
#  'Parken_stadium',
#  'GotVoice',
#  'Alfreton_Town',
#  'Herman',
#  'GROWING_BUSINESS',
#  'Antonio_Meucci',
#  'ePharmaSolutions',
#  'Strategies_Analyses',
#  'Parmalat_SpA_PLT',
#  'Melvyn_Bragg',
#  'Juan_Pietravallo',
#  'nSIN######',
#  'Kuveyt_Turk',
#  'Gob_Squad',
#  'Wes_Littleton',
#  'Linnear',
#  'Muntilan_Central',
#  'counterpart_Luis_Amado',
#  'Ukraine_Yaroslav_Popovych',
#  'Hockmuth',
#  'NSCA_Expo',
#  'Junnarkar',
#  'Attorney_Fred_Wyshak',
#  'biocomposite',
#  'CEO_Jim_Brexler',
#  'CASA_volunteers',
#  'Richard_Diebenkorn_Roy_Lichtenstein',
#  'Dhari_Ali',
#  'chair_Salamat_Hashim',
#  'Wireless_Intel_SpeedStep',
#  'Eretz_Nehederet',
#  'Broback',
#  'involve_risks_anduncertainties',
#  'PRNewswire_FirstCall_TRW_Automotive',
#  'Kali_Yuga',
#  'Peru_La_Republica',
#  'www.cheniere.com',
#  'Carette',
#  'ElBaradei_reappointment',
#  'Safety_Authority_Evira',
#  'Sayed_Zahid_Hussain',
#  'acute_pharyngitis',
#  'André_Soltner',
#  'CANADIAN_PACIFIC',
#  'Inc_OSIS',
#  'spokesman_Alan_Bernheimer',
#  '##/#b_Paquette',
#  'Derrick_Hasterok_graduate',
#  'Manohari',
#  'mirtazapine',
#  'Hibbett_Sports_HIBB',
#  'Veronica_Mars_UPN',
#  'bares_resemblance',
#  'Guignol_Theatre',
#  'Divesh_Sisodraker',
#  'desiccant',
#  'wedge_Hole_TC##',
#  'WHITEHURST',
#  'NFS_Underground',
#  'recaptures',
#  'concoction',
#  'nasal_ointment',
#  'Lightin_Hopkins',
#  'rxRNA_™_compounds',
#  'PAT_KROCHMAL_pkrochmal@pioneerlocal.com',
#  'John_Potbury',
#  'french_fries_hash_browns',
#  'Buhbut',
#  'Cadence_Cadence',
#  'Stephen_Kiehl',
#  'oceanfront_condominium',
#  'Africa_reporter_Ashenafi',
#  'assorted_paraphernalia',
#  'submarines_headlamps',
#  'Von_Zamft',
#  'Mike_Accavitti',
#  'Crudes',
#  'Eunice_Peixoto_de',
#  'Hashizume',
#  'www.interflora.co.uk_Web',
#  'PH_Breakaway',
#  'website_www.walterbrasch.com',
#  'Bhavin_Thakkar',
#  'Bond',
#  'Masques',
#  'Integer_Overflow_Vulnerability',
#  'Bert_Bolin',
#  'roject',
#  'CHIM',
#  'Greg_Jergeson',
#  'Copa_de_Oro',
#  'Pay_Restitution',
#  'sewing_accessories_needlecraft',
#  'Research_Anuj_Singhal',
#  'Schuering',
#  'MIDNAPORE',
#  "SEC'Y",
#  'Jonathan_Motzfeldt',
#  '#.#m_hectoliters',
#  'Rebelyn_Pitao',
#  'JEAN_MICHEL',
#  'Kaupin',
#  'Ditan',
#  'Erik_Posz_Staff_Writer',
#  'Best_Editorial_Cartoons',
#  'mothering_skills',
#  'Pregont',
#  'Must_Disarm',
#  'NICKLAS_LIDSTROM',
#  'Sam_Bilney',
#  'visit_www.lcsd.gov.hk_cp',
#  'Joe_Pug',
#  'immersion',
#  'Feltham_Middlesex',
#  'Upwardly_Mobile',
#  'Dr._Risal_Djohan',
#  'Pink_Pussycat',
#  'certified_lactation_consultant',
#  'Complan',
#  'Pearse_McCauley',
#  'Xolisa_Vapi',
#  'Asahi_Pilkington',
#  'acrylic_sphere',
#  "Emeric_d'",
#  'Telefónica_O2_UK',
#  'Greeces',
#  'utter_squalor',
#  'really_brainwashed_Geier',
#  'Click_AICI',
#  'Seipei',
#  'Coca_cola',
#  'PB2_gene',
#  'Rive_Gauche_collection',
#  'Leonor_Vivanco_Staff_Writer',
#  'Rosenbohm',
#  'M##',
#  'Patrick_Ballantine',
#  'BASEL_Switzerland_Novartis_AG',
#  'ROVs_remotely_operated',
#  'Eldrick_Woods',
#  'KSTP.com',
#  'Sunya',
#  'Ingliston',
#  'Falt',
#  'outermost_fringes',
#  'Schroers',
#  'intravenous_tube',
#  'Callaloo',
#  'blowout_preventers',
#  'outdated_unsuited',
#  'DoubleLine_Capital',
#  'Alicia_Inns_KTVZ.COM',
#  'Listwin',
#  'Al_Badeel',
#  'Omer_Munoz',
#  'Kaizer_Motaung_Jr',
#  'website_RevolutionMuslim.com',
#  'triac',
#  'clot_formation',
#  'Guilderson',
#  'Upper_Ferntree_Gully',
#  'Badri_Kumar_Basnet',
#  'envoy_Jon_Hanssen',
#  'chemotherapy_FOLFOX',
#  'Paul_Casciato_editing',
#  'MCLC_MCLC',
#  'snowy_grouper',
#  'dryer_sheets',
#  'TSX_ZEN',
#  'CompCare',
#  'CGIA',
#  'Rowley_Chao',
#  'McIlvene',
#  'ratify',
#  'Schils',
#  'Paron_High',
#  'Michael_LoGrande',
#  'Muhammad_Maqbool_Butt',
#  'attests',
#  'SUCH_CLAIM',
#  'Alarmist',
#  'Multiplo_TM_brands',
#  'Tacoma_WA_#####-####',
#  'Lejla_Hodzic',
#  'sous_chefs',
#  'Playaz',
#  'Nakayama_Racecourse',
#  'Faun',
#  'STRETCH_seating',
#  'DE_SILVA',
#  'Stacey_Farnen_Bernards',
#  'GJ_Muchall',
#  'R._Marak',
#  'Rs##_lakhs',
#  'Admiral_Semmes',
#  'HNT',
#  'Karen_Gadbois',
#  'dealer_Venson_Evangelista',
#  'Sandip_Shah',
#  'superwide_printing',
#  'SAMUEL_M._SIMPKINS',
#  'BDI_Pharma_Inc.',
#  'Tinies',
#  'liberté_égalité_fraternité',
#  'Huhn_MD_FACS',
#  'Golda_Och',
#  'Kiss_Me_Guido',
#  'Chris_Satullo',
#  'Squaw',
#  'spokesman_Joe_Hodas',
#  'Eichenfield',
#  'MILAN_AFX_Italy',
#  'Texas',
#  'Nabakov',
#  'Belmopan',
#  'coelacanths',
#  'Muttahida_Qaumi',
#  'Mexico_Iberoamerican',
#  'P._Hettel',
#  'prisoners',
#  'fallaway_jumper',
#  'VIZ_Pictures',
#  'muzzles',
#  'Harycki',
#  'VB_Script',
#  'secretary_Romano_Kiome',
#  'Ruminants',
#  'methodological_limitations',
#  'CANTON_Mich.',
#  'Romaniello',
#  'Ashmole',
#  'Cerebro',
#  'ska_punk_band',
#  'Ericka_Dunlap',
#  'Romania_libera_reads',
#  'ROBERT_HALF_INTERNATIONAL_INC.',
#  'BELIEFS_AS_TO',
#  'Jeff_Hullinger',
#  'Eladio_Jimenez',
#  'Gamaliel_Onosode',
#  'Esscor_Triconex_InFusion',
#  'sword_pommel',
#  'accidentally_punctured',
#  'Waytashek',
#  'shakier_ground',
#  'Guardian_Stockbrokers',
#  'defeated_Sorana_Cirstea',
#  'Bavaird',
#  'Dr._Donald_Rhodd',
#  'www.tundra.com',
#  'Barbeque_Pit',
#  'Todmorden_Borough',
#  'REDLANDS_Calif.',
#  'Bernice_Torregrossa',
#  'Super_Bowl_XXI',
#  'Cunha_MEN',
#  'leader_Josip_Broz',
#  '####-##_Lexus_ES###s',
#  'inverse_snobbery',
#  'Emile_Hirsch_Into',
#  'sato',
#  'Caroline_Seger',
#  'Janis_Smits',
#  'BELLATOR_NEWS',
#  'Chenery_Wickens',
#  'Force_Camp_Pendleton',
#  'buttery_puff_pastry',
#  'Dimension_Data_plc_LSE',
#  'Thomas_Okarma',
#  'Naspo',
#  'Crop_Forecasters',
#  'general_Solon_Nikitas',
#  'JCorp',
#  'navies_skirmished',
#  'Alfred_Kinsey',
#  'Hagart',
#  'Oneworld_airline',
#  'producer_Cecile_Frot',
#  'direk',
#  'Chiyoda_Corp',
#  'Pygmy_Hippo',
#  'Kino_Journey',
#  'Patient_Satisfaction',
#  'Teape',
#  "li'l_sis",
#  'Bulleen_Melbourne',
#  'CCCAA',
#  'College_Evelynn_M.',
#  'Van_Herp',
#  'nyse_DCX_news',
#  'Mahmoud_Khuzandar_deputy',
#  'sonA',
#  'woodsball',
#  'rounder_Irfan_Pathan',
#  'Ahmed_Adil_Abdallat',
#  'Boergers_lifelong_Democrat',
#  'BY_NICK_STUBBS',
#  'Education_SARE',
#  'MARFA_Texas',
#  'Tilsley',
#  'Lioness_Records',
#  'NFL_Mocks_Subscribe',
#  'Tafuna',
#  'execu',
#  'Whitehill_Bordon',
#  'CHRISTINE_RICCIARDI',
#  'Hryhoriy_Omelchenko',
#  'Nuns_auctioning_rare',
#  'famlies',
#  "A'Court",
#  '_Not',
#  'Rakon',
#  'Asaf_Ramon',
#  'Campark_Liquors_general',
#  'Crave_gadgets',
#  'Inc._NYSE_CLNY',
#  'Literary_footnotes',
#  'cavalier_attitude',
#  'Guadeloupe_Martinique']

# %%
embedded_vectors
# Out:
# array([[  4.858936 ,  -2.6397073],
#        [-10.385594 ,   5.620949 ],
#        [-11.581708 ,  -9.003298 ],
#        ...,
#        [  1.5655934,   9.303179 ],
#        [ -1.2254274,  -1.4092746],
#        [ -0.9839843,  -7.062248 ]], dtype=float32)
